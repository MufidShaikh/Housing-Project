# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
df=pd.read_csv('train.csv')
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='PoolQC',data=df)
# Out:
# <AxesSubplot:xlabel='PoolQC', ylabel='count'>

# %% [markdown]
# # Null Values

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df.isnull().transpose())
# Out:
# <AxesSubplot:>

# %%
#Low number of null values
#df["MasVnrType"].fillna('None', inplace = True) #lowO
df["BsmtQual"].fillna('No Basement', inplace = True) #lowO
df["BsmtCond"].fillna('No Basement', inplace = True) #lowO
df["BsmtExposure"].fillna('No Basement', inplace = True) #lowO
df["BsmtFinType1"].fillna('No Basement', inplace = True) #lowO
df["BsmtFinType2"].fillna('No Basement', inplace = True) #lowO
df["GarageType"].fillna('No Garage', inplace = True)  #lowO
df["GarageFinish"].fillna('No Garage', inplace = True) #lowO
df["GarageQual"].fillna('No Garage', inplace = True)  #lowO
df["GarageCond"].fillna('No Garage', inplace = True)  #lowO

df["MasVnrArea"].fillna(np.mean(df["MasVnrArea"]), inplace = True) #lowF
df["GarageYrBlt"].fillna(np.mean(df["GarageYrBlt"]), inplace = True) #lowF

# %%
#High number of null values
df["PoolQC"].fillna("No Pool", inplace = True)  #lots
df["Fence"].fillna("No Fence", inplace = True)   #lots
df["MiscFeature"].fillna("None", inplace = True)  #lots
df["Alley"].fillna("No Alley access", inplace = True) #lots
df["FireplaceQu"].fillna("No Fireplace", inplace = True) #lots

df.dropna(inplace=True)

# %%
for i in df.select_dtypes(['object']).columns:
    print(i,": ",df[i].unique())
# Out:
# MSZoning :  ['RL' 'RM' 'FV' 'RH' 'C (all)']
# Street :  ['Pave' 'Grvl']
# Alley :  ['No Alley access' 'Grvl' 'Pave']
# LotShape :  ['IR1' 'Reg' 'IR2' 'IR3']
# LandContour :  ['Lvl' 'Bnk' 'HLS' 'Low']
# Utilities :  ['AllPub']
# LotConfig :  ['Inside' 'CulDSac' 'Corner' 'FR2' 'FR3']
# LandSlope :  ['Mod' 'Gtl' 'Sev']
# Neighborhood :  ['NAmes' 'NoRidge' 'NWAmes' 'Gilbert' 'Sawyer' 'Edwards' 'IDOTRR'
#  'CollgCr' 'Mitchel' 'Crawfor' 'BrDale' 'StoneBr' 'BrkSide' 'NridgHt'
#  'OldTown' 'Somerst' 'Timber' 'SWISU' 'SawyerW' 'Veenker' 'ClearCr'
#  'Blmngtn' 'NPkVill' 'MeadowV' 'Blueste']
# Condition1 :  ['Norm' 'Feedr' 'RRAn' 'RRAe' 'Artery' 'PosN' 'RRNn' 'PosA' 'RRNe']
# Condition2 :  ['Norm' 'Feedr' 'PosN' 'Artery' 'RRNn' 'PosA']
# BldgType :  ['1Fam' 'TwnhsE' 'Twnhs' '2fmCon' 'Duplex']
# HouseStyle :  ['1Story' '2Story' '1.5Fin' 'SFoyer' '1.5Unf' 'SLvl' '2.5Fin' '2.5Unf']
# RoofStyle :  ['Flat' 'Gable' 'Hip' 'Gambrel' 'Mansard']
# ...

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df.isnull().transpose())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Graphical Relation

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street            Alley  \
# 1      889          20       RL         95.0    15865   Pave  No Alley access
# 2      793          60       RL         92.0     9920   Pave  No Alley access
# 3      110          20       RL        105.0    11751   Pave  No Alley access
# 5     1197          60       RL         58.0    14054   Pave  No Alley access
# 7     1041          20       RL         88.0    13125   Pave  No Alley access
# ...    ...         ...      ...          ...      ...    ...              ...
# 1160   551         120       RL         53.0     4043   Pave  No Alley access
# 1162  1381          30       RL         45.0     8212   Pave             Grvl
# 1164   554          20       RL         67.0     8777   Pave  No Alley access
# 1165   196         160       RL         24.0     2280   Pave  No Alley access
# 1166    31          70  C (all)         50.0     8500   Pave             Pave
#
# ...

# %%
sns.catplot(data=df,x='LotShape',y='LotArea',hue='LotConfig')

# %%
sns.catplot(data=df,x='LotShape',y='LotArea')

# %%
plt.scatter(data=df,x='LotArea',y='LotFrontage')

# %%
sns.catplot(data=df,x='BsmtFinType1',y='BsmtFinSF1')

# %%
sns.catplot(data=df,x='BsmtFinType2',y='BsmtFinSF2')

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=df,x='Heating',hue='HeatingQC')
# Out:
# <AxesSubplot:xlabel='Heating', ylabel='count'>

# %%
plt.scatter(data=df,y='1stFlrSF',x='LowQualFinSF')

# %%
plt.scatter(data=df,y='2ndFlrSF',x='LowQualFinSF')

# %%
plt.scatter(data=df,y='GrLivArea',x='LowQualFinSF')

# %%
sns.countplot(data=df,hue='BsmtFullBath',x='BsmtHalfBath')
# Out:
# <AxesSubplot:xlabel='BsmtHalfBath', ylabel='count'>

# %%
sns.countplot(data=df,hue='KitchenQual',x='KitchenAbvGr')
# Out:
# <AxesSubplot:xlabel='KitchenAbvGr', ylabel='count'>

# %%
sns.countplot(data=df,hue='FireplaceQu',x='Fireplaces')
# Out:
# <AxesSubplot:xlabel='Fireplaces', ylabel='count'>

# %%
sns.catplot(data=df,hue='GarageFinish',y='GarageArea',x='GarageQual')

# %%
sns.catplot(data=df,x='GarageCars',y='GarageArea')

# %%
sns.catplot(data=df,y='PoolArea',x='PoolQC')

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=df,x='SaleType')
# Out:
# <AxesSubplot:xlabel='SaleType', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=df,x='SaleCondition')
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='count'>

# %%
help(sns.factorplot)
# Out:
# Help on function factorplot in module seaborn.categorical:
#
# factorplot(*args, **kwargs)
#     Deprecated; please use `catplot` instead.

# %% [markdown]
# # Data Description

# %%
df.describe(include='all')
# Out:
#                  Id  MSSubClass MSZoning  LotFrontage       LotArea Street  \
# count    949.000000  949.000000      949   949.000000    949.000000    949
# unique          NaN         NaN        5          NaN           NaN      2
# top             NaN         NaN       RL          NaN           NaN   Pave
# freq            NaN         NaN      736          NaN           NaN    946
# mean     720.255005   57.239199      NaN    70.965227   9835.208641    NaN
# std      414.842983   42.814568      NaN    24.825804   5335.265011    NaN
# min        1.000000   20.000000      NaN    21.000000   1300.000000    NaN
# 25%      359.000000   20.000000      NaN    60.000000   7500.000000    NaN
# 50%      711.000000   50.000000      NaN    70.000000   9350.000000    NaN
# 75%     1075.000000   70.000000      NaN    80.000000  11207.000000    NaN
# max     1460.000000  190.000000      NaN   313.000000  70761.000000    NaN
#
# ...

# %%
plt.figure(figsize=(18,18))
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Applying Encoder

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
col=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition']

for i in col:
    df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %% [markdown]
# # Data Description After Encoder

# %%
plt.figure(figsize=(18,30))
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Correlation with 'SalesPrice'

# %%
plt.figure(figsize=(20,7))
df.corr()['SalePrice'].sort_values(ascending=False).drop(['SalePrice']).plot(kind='bar',color='maroon')
plt.xlabel('Attributes',fontsize=12)
plt.ylabel('Columns With Target Names',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %%
df.corr()['SalePrice']
# Out:
# Id              -0.045882
# MSSubClass      -0.073740
# MSZoning        -0.134675
# LotFrontage      0.339500
# LotArea          0.370734
#                    ...
# MoSold           0.081789
# YrSold          -0.032588
# SaleType        -0.058450
# SaleCondition    0.243853
# SalePrice        1.000000
# Name: SalePrice, Length: 81, dtype: float64

# %%
from scipy.stats import zscore
z=np.abs(zscore(df.drop(['SalePrice'],axis=1)))
z.shape
# Out:
# (949, 80)

# %%
df_new=df
x=df_new.drop(['SalePrice'],axis=1)
y=df_new['SalePrice']

# %%
df_new
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 1      889          20         3         95.0    15865       1      1
# 2      793          60         3         92.0     9920       1      1
# 3      110          20         3        105.0    11751       1      1
# 5     1197          60         3         58.0    14054       1      1
# 7     1041          20         3         88.0    13125       1      1
# ...    ...         ...       ...          ...      ...     ...    ...
# 1160   551         120         3         53.0     4043       1      1
# 1162  1381          30         3         45.0     8212       1      0
# 1164   554          20         3         67.0     8777       1      1
# 1165   196         160         3         24.0     2280       1      1
# 1166    31          70         0         50.0     8500       1      2
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %% [markdown]
# # Skew

# %%
x.skew()
# Out:
# Id               0.038432
# MSSubClass       1.437015
# MSZoning        -1.764246
# LotFrontage      2.465931
# LotArea          4.625729
#                    ...
# MiscVal          9.447027
# MoSold           0.182543
# YrSold           0.121589
# SaleType        -3.551146
# SaleCondition   -2.571016
# Length: 80, dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x.skew()
# Out:
# Id              -0.266094
# MSSubClass       0.068043
# MSZoning         0.183037
# LotFrontage      0.107069
# LotArea          0.138201
#                    ...
# MiscVal          5.463514
# MoSold          -0.038334
# YrSold           0.118549
# SaleType        -1.885760
# SaleCondition   -0.374293
# Length: 80, dtype: float64

# %% [markdown]
# # Model Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
maxAcc=0
maxRS=0
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(x,y,test_size=.20,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    acc=r2_score(target_test,pred_test)
    if(acc>maxAcc):
        maxAcc=acc
        maxRS=i
print("Best accuracy: ",maxAcc," on Random State: ",maxRS)
# Out:
# Best accuracy:  0.8754029467788838  on Random State:  67

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()

kmaxAcc=0
kmaxRS=0
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(x,y,test_size=.20,random_state=i)
    knr.fit(features_train,target_train)
    pred_train=knr.predict(features_train)
    pred_test=knr.predict(features_test)
    acc=r2_score(target_test,pred_test)
    if(acc>kmaxAcc):
        kmaxAcc=acc
        kmaxRS=i
print("Best accuracy: ",kmaxAcc," on Random State: ",kmaxRS)
# Out:
# Best accuracy:  0.8339824374197873  on Random State:  67

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()

dmaxAcc=0
dmaxRS=0
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(x,y,test_size=.20,random_state=i)
    dtr.fit(features_train,target_train)
    pred_train=dtr.predict(features_train)
    pred_test=dtr.predict(features_test)
    acc=r2_score(target_test,pred_test)
    if(acc>dmaxAcc):
        dmaxAcc=acc
        dmaxRS=i
print("Best accuracy: ",dmaxAcc," on Random State: ",dmaxRS)
# Out:
# Best accuracy:  0.8321941466109577  on Random State:  65

# %%
from sklearn.svm import SVR
sv=SVR(kernel='linear')

smaxAcc=0
smaxRS=0
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(x,y,test_size=.20,random_state=i)
    sv.fit(features_train,target_train)
    pred_train=sv.predict(features_train)
    pred_test=sv.predict(features_test)
    acc=r2_score(target_test,pred_test)
    if(acc>smaxAcc):
        smaxAcc=acc
        smaxRS=i
print("Best accuracy: ",smaxAcc," on Random State: ",smaxRS)
# Out:
# Best accuracy:  0.1535975727119312  on Random State:  13

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

rmaxAcc=0
rmaxRS=0
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(x,y,test_size=.20,random_state=i)
    rf.fit(features_train,target_train)
    pred_train=rf.predict(features_train)
    pred_test=rf.predict(features_test)
    acc=r2_score(target_test,pred_test)
    if(acc>rmaxAcc):
        rmaxAcc=acc
        rmaxRS=i
print("Best accuracy: ",rmaxAcc," on Random State: ",rmaxRS)
# Out:
# Best accuracy:  0.9202026975206257  on Random State:  66

# %% [markdown]
# - Decision Tree Regressor Model has shown the best results with Linear Regresson Model having a very close accuracy.
# - Whereas Support Vector Regressor has a very bad accuracy score.

# %%
features_train,features_test,target_train,target_test=train_test_split(x,y,random_state=66,test_size=0.20)

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(rf,x,y,cv=5)
print('Cross validation score is: ',scr.mean())
# Out:
# Cross validation score is:  0.8271474896079637

# %% [markdown]
# # Hyper Tuning

# %%
from sklearn.model_selection import GridSearchCV
parameters={'criterion':["squared_error", "absolute_error", "poisson"],
           'max_depth':range(1,10,2),
           'max_features':["auto", "sqrt", "log2"],
           'ccp_alpha':[0.0001,0.001,0.01,0.1,1,10]}
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'ccp_alpha': 0.1, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 'sqrt'}

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(ccp_alpha=0.1,criterion='squared_error',max_depth=9,max_features='sqrt')

rmaxAcc=0
rmaxRS=0
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(x,y,test_size=.20,random_state=i)
    rf.fit(features_train,target_train)
    pred_train=rf.predict(features_train)
    pred_test=rf.predict(features_test)
    acc=r2_score(target_test,pred_test)
    if(acc>rmaxAcc):
        rmaxAcc=acc
        rmaxRS=i
print("Best accuracy: ",rmaxAcc," on Random State: ",rmaxRS)
# Out:
# Best accuracy:  0.9101660635992742  on Random State:  29

# %% [markdown]
# # AUC ROC

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test,y=pred_test,color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Actual Sales',fontsize=14)
plt.ylabel('Predicted Sales',fontsize=14)
plt.title('DecisionTree Regressor',fontsize=18)
plt.show()

# %%
import joblib
joblib.dump(rf,'Housing Project Model.pkl')
# Out:
# ['Housing Project Model.pkl']

# %% [markdown]
# # Testing

# %%
dfx=pd.read_csv('test.csv')
dfx
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %%
#Low number of null values
dfx["MasVnrType"].fillna('None', inplace = True) #lowO
dfx["BsmtQual"].fillna('TA', inplace = True) #lowO
dfx["BsmtCond"].fillna('TA', inplace = True) #lowO
dfx["BsmtExposure"].fillna('No', inplace = True) #lowO
dfx["BsmtFinType1"].fillna('Unf', inplace = True) #lowO
dfx["BsmtFinType2"].fillna('Unf', inplace = True) #lowO
dfx["GarageType"].fillna('Attchd', inplace = True)  #lowO
dfx["GarageFinish"].fillna('Unf', inplace = True) #lowO
dfx["GarageQual"].fillna('TA', inplace = True)  #lowO
dfx["GarageCond"].fillna('TA', inplace = True)  #lowO

dfx["MasVnrArea"].fillna(np.mean(dfx["MasVnrArea"]), inplace = True) #lowF
dfx["GarageYrBlt"].fillna(np.mean(dfx["GarageYrBlt"]), inplace = True) #lowF

# %%
#High number of null values
dfx["PoolQC"].fillna("No Pool", inplace = True)  #lots
dfx["Fence"].fillna("No Fence", inplace = True)   #lots
dfx["MiscFeature"].fillna("None", inplace = True)  #lots
#df["LotFrontage"].fillna("", inplace = True) #lots
dfx["Alley"].fillna("No alley access", inplace = True) #lots
dfx["FireplaceQu"].fillna("No Fireplace", inplace = True) #lots

dfx.dropna(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
col=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition']

for i in col:
    dfx[i]=enc.fit_transform(dfx[i].values.reshape(-1,1))

# %%
model=joblib.load('Housing Project Model.pkl')

#Use the loaded model to make predictions
prediction=model.predict(dfx)
prediction.astype(np.float)
dfx['SalePrice']=prediction
pd.set_option('display.float_format', lambda x: '%.2f' % x)
dfx
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     337          20         2        86.00    14157       1      1
# 3    1148          70         2        75.00    12000       1      1
# 4    1227          60         2        86.00    14598       1      1
# 5     650         180         3        21.00     1936       1      1
# 6    1453         180         3        35.00     3675       1      1
# ..    ...         ...       ...          ...      ...     ...    ...
# 286    56          20         2       100.00    10175       1      1
# 287    83          20         2        78.00    10206       1      1
# 288  1048          20         2        57.00     9245       1      1
# 290   523          50         3        50.00     5000       1      1
# 291  1379         160         3        21.00     1953       1      1
#
#      LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# 0           0            1          0  ...         0       0      4
# ...

# %%
dfx.to_csv('Predicted Test.csv',index=False)

# %%
prediction
# Out:
# array([423796.07833333, 421938.76928571, 446089.59761905, 330518.02364035,
#        411083.8675    , 412775.93833333, 417681.68333333, 342151.18495671,
#        350263.64829004, 420285.38227273, 392802.22352814, 408878.72928571,
#        381063.73595238, 455627.065     , 428209.45428571, 415750.52928571,
#        386525.15095238, 315747.09145229, 371172.12595238, 383271.23595238,
#        412370.40904762, 409114.665     , 458705.495     , 343648.95495671,
#        365995.96434921, 408794.225     , 392856.45595238, 417707.455     ,
#        341626.68495671, 408993.13904762, 460263.455     , 452427.925     ,
#        430243.68928571, 378672.04595238, 463335.695     , 384709.07595238,
#        379298.29595238, 411973.49928571, 379670.06595238, 341143.88829004,
#        415688.73      , 434167.80277778, 418837.03928571, 386582.00495671,
#        340116.07495671, 433329.03761905, 392643.91495671, 417501.97904762,
# ...
